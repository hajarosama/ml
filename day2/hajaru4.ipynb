# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()


x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0


y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)


class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck'
]


plt.figure(figsize=(10, 4))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i])
    plt.xticks([])
    plt.yticks([])
    plt.title(class_names[np.argmax(y_train[i])])

plt.show()

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 1555s 9us/step
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])


model = models.Sequential([

    data_augmentation,


    layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                  input_shape=(32, 32, 3)),
    layers.BatchNormalization(),

    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),


    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),


    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),


    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),


    layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)


early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)


checkpoint = ModelCheckpoint(
    'best_cnn_model.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=128,
    validation_split=0.1,
    shuffle=True,
    callbacks=[reduce_lr, early_stop, checkpoint]
)
# Out:
# Epoch 1/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 996ms/step - accuracy: 0.3019 - loss: 2.2235
# Epoch 1: val_accuracy improved from None to 0.28280, saving model to best_cnn_model.keras
#
# Epoch 1: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 369s 1s/step - accuracy: 0.3733 - loss: 1.8577 - val_accuracy: 0.2828 - val_loss: 2.3820 - learning_rate: 0.0010
# Epoch 2/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.4818 - loss: 1.4390
# Epoch 2: val_accuracy improved from 0.28280 to 0.57980, saving model to best_cnn_model.keras
#
# Epoch 2: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.5029 - loss: 1.3798 - val_accuracy: 0.5798 - val_loss: 1.2052 - learning_rate: 0.0010
# Epoch 3/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5542 - loss: 1.2553
# Epoch 3: val_accuracy improved from 0.57980 to 0.58540, saving model to best_cnn_model.keras
#
# Epoch 3: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.5654 - loss: 1.2209 - val_accuracy: 0.5854 - val_loss: 1.1848 - learning_rate: 0.0010
# Epoch 4/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5974 - loss: 1.1424
# Epoch 4: val_accuracy improved from 0.58540 to 0.63600, saving model to best_cnn_model.keras
#
# Epoch 4: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 365s 1s/step - accuracy: 0.6058 - loss: 1.1182 - val_accuracy: 0.6360 - val_loss: 1.0313 - learning_rate: 0.0010
# Epoch 5/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6341 - loss: 1.0497
# Epoch 5: val_accuracy improved from 0.63600 to 0.66420, saving model to best_cnn_model.keras
#
# Epoch 5: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.6360 - loss: 1.0426 - val_accuracy: 0.6642 - val_loss: 0.9494 - learning_rate: 0.0010
# Epoch 6/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.6493 - loss: 0.9980
# Epoch 6: val_accuracy improved from 0.66420 to 0.68760, saving model to best_cnn_model.keras
#
# Epoch 6: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.6548 - loss: 0.9870 - val_accuracy: 0.6876 - val_loss: 0.9141 - learning_rate: 0.0010
# Epoch 7/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6722 - loss: 0.9477
# Epoch 7: val_accuracy did not improve from 0.68760
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - accuracy: 0.6753 - loss: 0.9415 - val_accuracy: 0.6848 - val_loss: 0.9099 - learning_rate: 0.0010
# Epoch 8/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6800 - loss: 0.9224
# Epoch 8: val_accuracy improved from 0.68760 to 0.71200, saving model to best_cnn_model.keras
#
# Epoch 8: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.6863 - loss: 0.9083 - val_accuracy: 0.7120 - val_loss: 0.8484 - learning_rate: 0.0010
# Epoch 9/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6984 - loss: 0.8744
# Epoch 9: val_accuracy did not improve from 0.71200
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 366s 1s/step - accuracy: 0.7011 - loss: 0.8673 - val_accuracy: 0.7020 - val_loss: 1.3742 - learning_rate: 0.0010
# Epoch 10/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7106 - loss: 0.8386
# Epoch 10: val_accuracy improved from 0.71200 to 0.71560, saving model to best_cnn_model.keras
#
# Epoch 10: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 363s 1s/step - accuracy: 0.7104 - loss: 0.8393 - val_accuracy: 0.7156 - val_loss: 0.8453 - learning_rate: 0.0010
# Epoch 11/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.7198 - loss: 0.8186
# Epoch 11: val_accuracy improved from 0.71560 to 0.76400, saving model to best_cnn_model.keras
#
# Epoch 11: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 380s 1s/step - accuracy: 0.7227 - loss: 0.8117 - val_accuracy: 0.7640 - val_loss: 0.6915 - learning_rate: 0.0010
# Epoch 12/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7327 - loss: 0.7862
# Epoch 12: val_accuracy did not improve from 0.76400
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.7327 - loss: 0.7864 - val_accuracy: 0.7476 - val_loss: 0.7415 - learning_rate: 0.0010
# Epoch 13/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.7365 - loss: 0.7611
# Epoch 13: val_accuracy improved from 0.76400 to 0.79520, saving model to best_cnn_model.keras
#
# Epoch 13: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.7352 - loss: 0.7688 - val_accuracy: 0.7952 - val_loss: 0.6104 - learning_rate: 0.0010
# Epoch 14/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1000ms/step - accuracy: 0.7436 - loss: 0.7475
# Epoch 14: val_accuracy did not improve from 0.79520
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.7438 - loss: 0.7502 - val_accuracy: 0.7616 - val_loss: 0.7143 - learning_rate: 0.0010
# Epoch 15/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7481 - loss: 0.7362
# Epoch 15: val_accuracy did not improve from 0.79520
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.7512 - loss: 0.7272 - val_accuracy: 0.7534 - val_loss: 0.7295 - learning_rate: 0.0010
# Epoch 16/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.7591 - loss: 0.7044
# Epoch 16: val_accuracy did not improve from 0.79520
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - accuracy: 0.7575 - loss: 0.7068 - val_accuracy: 0.7736 - val_loss: 0.6743 - learning_rate: 0.0010
# Epoch 17/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7634 - loss: 0.6914
# Epoch 17: val_accuracy did not improve from 0.79520
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.7626 - loss: 0.6933 - val_accuracy: 0.7930 - val_loss: 0.6093 - learning_rate: 0.0010
# Epoch 18/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7684 - loss: 0.6802
# Epoch 18: val_accuracy did not improve from 0.79520
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.7654 - loss: 0.6906 - val_accuracy: 0.7856 - val_loss: 0.6370 - learning_rate: 0.0010
# Epoch 19/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 995ms/step - accuracy: 0.7729 - loss: 0.6576
# Epoch 19: val_accuracy did not improve from 0.79520
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 379s 1s/step - accuracy: 0.7733 - loss: 0.6648 - val_accuracy: 0.7846 - val_loss: 0.6422 - learning_rate: 0.0010
# Epoch 20/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7742 - loss: 0.6625
# Epoch 20: val_accuracy improved from 0.79520 to 0.80840, saving model to best_cnn_model.keras
#
# Epoch 20: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.7737 - loss: 0.6599 - val_accuracy: 0.8084 - val_loss: 0.5776 - learning_rate: 0.0010
# Epoch 21/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7792 - loss: 0.6433
# Epoch 21: val_accuracy improved from 0.80840 to 0.81180, saving model to best_cnn_model.keras
#
# Epoch 21: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.7801 - loss: 0.6430 - val_accuracy: 0.8118 - val_loss: 0.5617 - learning_rate: 0.0010
# Epoch 22/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7810 - loss: 0.6402
# Epoch 22: val_accuracy did not improve from 0.81180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 378s 1s/step - accuracy: 0.7816 - loss: 0.6407 - val_accuracy: 0.7792 - val_loss: 0.6733 - learning_rate: 0.0010
# Epoch 23/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7874 - loss: 0.6204
# Epoch 23: val_accuracy did not improve from 0.81180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.7857 - loss: 0.6282 - val_accuracy: 0.8072 - val_loss: 0.5559 - learning_rate: 0.0010
# Epoch 24/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7888 - loss: 0.6171
# Epoch 24: val_accuracy improved from 0.81180 to 0.82180, saving model to best_cnn_model.keras
#
# Epoch 24: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 363s 1s/step - accuracy: 0.7865 - loss: 0.6257 - val_accuracy: 0.8218 - val_loss: 0.5406 - learning_rate: 0.0010
# Epoch 25/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7889 - loss: 0.6049
# Epoch 25: val_accuracy did not improve from 0.82180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 364s 1s/step - accuracy: 0.7894 - loss: 0.6103 - val_accuracy: 0.8044 - val_loss: 0.5986 - learning_rate: 0.0010
# Epoch 26/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.7901 - loss: 0.6160
# Epoch 26: val_accuracy did not improve from 0.82180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 380s 1s/step - accuracy: 0.7929 - loss: 0.6089 - val_accuracy: 0.8212 - val_loss: 0.5448 - learning_rate: 0.0010
# Epoch 27/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7971 - loss: 0.5898
# Epoch 27: val_accuracy did not improve from 0.82180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.7944 - loss: 0.5955 - val_accuracy: 0.8144 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 28/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.7983 - loss: 0.5946
# Epoch 28: val_accuracy did not improve from 0.82180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.7991 - loss: 0.5924 - val_accuracy: 0.8066 - val_loss: 0.5888 - learning_rate: 0.0010
# Epoch 29/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8020 - loss: 0.5815
# Epoch 29: val_accuracy improved from 0.82180 to 0.82860, saving model to best_cnn_model.keras
#
# Epoch 29: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.7997 - loss: 0.5857 - val_accuracy: 0.8286 - val_loss: 0.5193 - learning_rate: 0.0010
# Epoch 30/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.7995 - loss: 0.5848
# Epoch 30: val_accuracy did not improve from 0.82860
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 379s 1s/step - accuracy: 0.8015 - loss: 0.5806 - val_accuracy: 0.8282 - val_loss: 0.5061 - learning_rate: 0.0010
# Epoch 31/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8050 - loss: 0.5710
# Epoch 31: val_accuracy improved from 0.82860 to 0.83080, saving model to best_cnn_model.keras
#
# Epoch 31: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.8058 - loss: 0.5698 - val_accuracy: 0.8308 - val_loss: 0.4949 - learning_rate: 0.0010
# Epoch 32/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8057 - loss: 0.5643
# Epoch 32: val_accuracy improved from 0.83080 to 0.83420, saving model to best_cnn_model.keras
#
# Epoch 32: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 364s 1s/step - accuracy: 0.8080 - loss: 0.5613 - val_accuracy: 0.8342 - val_loss: 0.5102 - learning_rate: 0.0010
# Epoch 33/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8076 - loss: 0.5577
# Epoch 33: val_accuracy did not improve from 0.83420
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.8067 - loss: 0.5663 - val_accuracy: 0.8324 - val_loss: 0.5093 - learning_rate: 0.0010
# Epoch 34/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8102 - loss: 0.5519
# Epoch 34: val_accuracy did not improve from 0.83420
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.8086 - loss: 0.5559 - val_accuracy: 0.8080 - val_loss: 0.5758 - learning_rate: 0.0010
# Epoch 35/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8140 - loss: 0.5486
# Epoch 35: val_accuracy did not improve from 0.83420
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 361s 1s/step - accuracy: 0.8120 - loss: 0.5515 - val_accuracy: 0.8096 - val_loss: 0.5920 - learning_rate: 0.0010
# Epoch 36/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.8128 - loss: 0.5433
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 36: val_accuracy did not improve from 0.83420
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - accuracy: 0.8118 - loss: 0.5478 - val_accuracy: 0.8138 - val_loss: 0.5525 - learning_rate: 0.0010
# Epoch 37/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8209 - loss: 0.5216
# Epoch 37: val_accuracy improved from 0.83420 to 0.84680, saving model to best_cnn_model.keras
#
# Epoch 37: finished saving model to best_cnn_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 362s 1s/step - accuracy: 0.8255 - loss: 0.5099 - val_accuracy: 0.8468 - val_loss: 0.4708 - learning_rate: 5.0000e-04
# Epoch 38/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8294 - loss: 0.4982
# Epoch 38: val_accuracy did not improve from 0.84680
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 364s 1s/step - accuracy: 0.8307 - loss: 0.4966 - val_accuracy: 0.8400 - val_loss: 0.4848 - learning_rate: 5.0000e-04
# Epoch 39/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - accuracy: 0.8332 - loss: 0.4902
# Epoch 39: val_accuracy did not improve from 0.84680
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 360s 1s/step - accuracy: 0.8331 - loss: 0.4881 - val_accuracy: 0.8348 - val_loss: 0.4860 - learning_rate: 5.0000e-04
# Epoch 40/40
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8358 - loss: 0.4799
# Epoch 40: val_accuracy did not improve from 0.84680
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.8322 - loss: 0.4873 - val_accuracy: 0.8444 - val_loss: 0.4691 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 40.

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('CNN Accuracy')
plt.legend()
plt.show()


plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('CNN Loss')
plt.legend()
plt.show()


test_loss, test_accuracy = model.evaluate(
    x_test,
    y_test,
    verbose=2
)

print("Test Accuracy:", test_accuracy)
print("Test Accuracy (%):", test_accuracy * 100)
# Out:
# 313/313 - 18s - 56ms/step - accuracy: 0.8396 - loss: 0.4829
# Test Accuracy: 0.8396000266075134
# Test Accuracy (%): 83.96000266075134

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import balanced_accuracy_score

y_prob = model.predict(x_test)
y_pred = np.argmax(y_prob, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Classification Report:")
print(classification_report(
    y_true,
    y_pred,
    target_names=class_names
))

cm = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(cm)

balanced_acc = balanced_accuracy_score(y_true, y_pred)
ber = 1 - balanced_acc

print("Balanced Accuracy:", balanced_acc)
print("BER:", ber)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.87      0.86      1000
#   automobile       0.90      0.95      0.93      1000
#         bird       0.82      0.78      0.80      1000
#          cat       0.81      0.61      0.70      1000
#         deer       0.78      0.85      0.81      1000
#          dog       0.84      0.70      0.76      1000
#         frog       0.74      0.94      0.83      1000
#        horse       0.85      0.89      0.87      1000
#         ship       0.91      0.92      0.92      1000
#        truck       0.90      0.88      0.89      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
#
# Confusion Matrix:
# [[866  17  29   7  12   2   4  10  35  18]
#  [  7 950   0   0   0   0   4   1   9  29]
#  [ 29   2 781  13  52  24  62  25   6   6]
#  [ 18  10  51 614  59  86 106  28  15  13]
#  [  9   1  28  12 854   7  54  33   2   0]
#  [  2   5  34  84  49 701  64  49   4   8]
#  [  3   1  12   9  18   2 938   5   7   5]
#  [  8   0   8  10  50  12  12 890   3   7]
#  [ 33   8   9   1   2   0   8   3 924  12]
#  [ 31  59   0   4   3   0   8   5  12 878]]
# Balanced Accuracy: 0.8395999999999999
# BER: 0.1604000000000001
